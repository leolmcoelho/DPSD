# %%
arquivo_configuracao = open('Configuracao_do_Stack.txt','r')
linhas = arquivo_configuracao.readlines()
a2 = int(linhas[3])-1;
b2 = int(linhas[5])-1;
c2 = int(linhas[7])-1;

# %%
from gui import Config

config = Config()

# %%
print(linhas[7])
print(c2)
# Out:
# 15
#
# 14

# %%
import json
with open('config.json', 'r') as f:
   config = json.load(f) 

pixels = config['pixels']
eixoX = pixels['X']-1
eixoY = pixels['Y']-1

arquivos = config['arquivo']
quantidade_imagens = arquivos['quantidade']-1
extensao = arquivos['extensao']
primeira_imagem = arquivos['primeira_imagem']
ultima_imagem = arquivos['ultima_imagem']




print(arquivos)
# Out:
# {'nome_comum': 'lva 3cm 29.9Âµm_al+cu__rec_bin0', 'primeira_imagem': 187, 'ultima_imagem': 201, 'extensao': '.bmp', 'quantidade': 15, 'tipos_aceitos': '.bmp e .tif'}
